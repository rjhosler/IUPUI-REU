# %%
import pandas as pd 
import numpy as np

# %%
fields = ['CALL_NO', 'UNIT_DISPATCH_DATE', 'Time of dispatch', 'CALL_TYPE_FINAL', 'CALL_TYPE_FINAL_D',  'XCOORD', 'YCOORD']

# %%
data = pd.read_csv('/home/march/Downloads/EMSDataFixed.csv', usecols=fields)
# Out:
# /home/march/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.isnull().sum(axis=0)
# Out:
# CALL_NO                   0
# UNIT_DISPATCH_DATE        0
# Time of dispatch      18317
# CALL_TYPE_FINAL           0
# CALL_TYPE_FINAL_D         0
# XCOORD                  619
# YCOORD                  619
# dtype: int64

# %%
# Rename Time of dispatch to DISPATCH_TIME
data.rename(columns={'Time of dispatch':'DISPATCH_TIME'}, inplace=True)

# %% [markdown]
# The 18,317 rows (out of 1018169) that are missing time of dispatch are the final 18,317 rows. This corresponds to dates from 11/01/2016 to 12/31/2016. For point process purposes, removing them from use.
#
# Run this for proof of that fact:
#
# time_isnull = data['Time of dispatch'].isnull()
# lastRead = False
# false_true_flip = []
# for i in range(0, len(time_isnull)):
#     if lastRead != time_isnull[i]:
#         false_true_flip.append(i)
#     lastRead = time_isnull[i]
# print(false_true_flip) # index of flip from False to True = [999852]

# %%
# Removing final 18317 rows
indexes_to_remove = []
for i in range(999852, len(data)):
    indexes_to_remove.append(i)
data.drop(data.index[indexes_to_remove], inplace=True)
data.isnull().sum(axis=0)
# Out:
# CALL_NO                 0
# UNIT_DISPATCH_DATE      0
# DISPATCH_TIME           0
# CALL_TYPE_FINAL         0
# CALL_TYPE_FINAL_D       0
# XCOORD                611
# YCOORD                611
# dtype: int64

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [20,10]
loc_null = data['XCOORD'].isnull()
# plt.plot(loc_null, '.')
# The distribution of lost data is *fairly* regular

# %% [markdown]
# There are 611 points without any coordinates, which comes out to 100.0*611/999852) = 0.0611% of the rows. As a first pass, deleting these rows from the dataframe as the amount (and distribution) seems small enough not to greatly affect the models.

# %%
data.isna().sum(axis = 0)
# Out:
# CALL_NO                 0
# UNIT_DISPATCH_DATE      0
# DISPATCH_TIME           0
# CALL_TYPE_FINAL         0
# CALL_TYPE_FINAL_D       0
# XCOORD                611
# YCOORD                611
# dtype: int64

# %%
data.dropna(axis=0, how='any', inplace=True)
data.isna().sum(axis = 0)
# Out:
# CALL_NO               0
# UNIT_DISPATCH_DATE    0
# DISPATCH_TIME         0
# CALL_TYPE_FINAL       0
# CALL_TYPE_FINAL_D     0
# XCOORD                0
# YCOORD                0
# dtype: int64

# %% [markdown]
# Also need to remove gps points that are obviously wrong. We are removing anything that is smaller than 37 long because that is in Kentucky, not Indiana.

# %%
data = data[data.XCOORD>38]
data.reset_index(drop=True, inplace=True)

# %%
# convert dispatch times into strings to manipulate into datetime, next three cells
data.DISPATCH_TIME = data.DISPATCH_TIME.astype(str)

# %%
fixed_times = []
for i in range(0, len(data)):
    time = data.DISPATCH_TIME[i]
    if len(time)<8:
        time = time.zfill(6)
        s = time
        t = iter(s)
        time = ':'.join(a+b for a,b in zip(t, t))
    fixed_times.append(time)

# %%
data.UNIT_DISPATCH_DATE = data.UNIT_DISPATCH_DATE.astype(str)

# %%
from datetime import datetime
datetimes = []
for i in range(0, len(data)):
    datetime_object = datetime.strptime(data.UNIT_DISPATCH_DATE[i] + fixed_times[i], '%Y-%m-%d%H:%M:%S')
    datetimes.append(datetime_object)

# %%
datetimes[len(data)-1]
# Out:
# datetime.datetime(2016, 10, 31, 23, 58, 3)

# %%
data['Date_Time '] = datetimes

# %%
data
# Out:
#           CALL_NO UNIT_DISPATCH_DATE DISPATCH_TIME CALL_TYPE_FINAL  \
# 0        61209515         2006-12-28        044548            773A
# 1        61209516         2006-12-28        044853            774A
# 2        61209517         2006-12-28        045219            768A
# 3        61209519         2006-12-28        051057            773A
# 4        61209520         2006-12-28        051756            790A
# 5        61209521         2006-12-28        051906            765A
# 6        61209522         2006-12-28        053302            773A
# 7        61209523         2006-12-28        053916            768A
# 8        61209524         2006-12-28        054924            770A
# 9        61209525         2006-12-28        060030            790A
# 10       61209526         2006-12-28        061515            792B
# 11       61209527         2006-12-28        060949            765A
# 12       61209528         2006-12-28        061921            765A
# 13       61209529         2006-12-28        061946            768A
# 14       61209530         2006-12-28        062503            768A
# 15       61209532         2006-12-28        062950            770A
# 16       61209534         2006-12-28        065645            790B
# 17       61209535         2006-12-28        070945            790A
# 18       61209536         2006-12-28        071529            792B
# 19       61209538         2006-12-28        072300            766A
# 20       61209539         2006-12-28        072819            766A
# 21       61209542         2006-12-28        075611            766A
# 22       61209543         2006-12-28        080339            773A
# 23       61209544         2006-12-28        080000            791A
# 24       61209545         2006-12-28        080051            775A
# 25       61209546         2006-12-28        080117            769B
# 26       61209549         2006-12-28        081044            766A
# 27       61209550         2006-12-28        081111            790B
# 28       61209551         2006-12-28        082139            771A
# 29       61209552         2006-12-28        082659            765A
# ...           ...                ...           ...             ...
# 922509  161015774         2016-10-31      21:57:41            765A
# 922510  161015776         2016-10-31      22:03:58            796B
# 922511  161015777         2016-10-31      22:07:45            792B
# 922512  161015779         2016-10-31      22:10:49            767A
# 922513  161015780         2016-10-31      22:16:23           784AU
# 922514  161015781         2016-10-31      22:19:34            766A
# 922515  161015783         2016-10-31      22:23:42            773A
# 922516  161015784         2016-10-31      22:32:17            790B
# 922517  161015785         2016-10-31      22:35:36            772A
# 922518  161015786         2016-10-31      22:35:42            773A
# 922519  161015787         2016-10-31      22:43:02            770A
# 922520  161015790         2016-10-31      22:48:33             805
# 922521  161015792         2016-10-31      22:55:22           774AU
# 922522  161015793         2016-10-31      22:55:31            792A
# 922523  161015794         2016-10-31      22:58:35            765A
# 922524  161015795         2016-10-31      23:03:41            770A
# 922525  161015797         2016-10-31      23:08:22            776A
# 922526  161015798         2016-10-31      23:15:03            766A
# 922527  161015799         2016-10-31      23:18:03            773A
# 922528  161015800         2016-10-31      23:21:20            791A
# 922529  161015802         2016-10-31      23:29:13            790A
# 922530  161015803         2016-10-31      23:30:41            784C
# 922531  161015804         2016-10-31      23:33:08            775A
# 922532  161015806         2016-10-31      23:35:01           791AW
# 922533  161015807         2016-10-31      23:36:42            768A
# 922534  161015809         2016-10-31      23:41:01            773A
# 922535  161015811         2016-10-31      23:46:36            790A
# 922536  161015814         2016-10-31      23:51:56            772A
# 922537  161015815         2016-10-31      23:55:25            766A
# 922538  161015816         2016-10-31      23:58:03            776A
#
#        CALL_TYPE_FINAL_D     XCOORD     YCOORD           DATE_TIME  \
# 0       UNCONSCIOUS PERS  39.824332 -86.236119 2006-12-28 04:48:53
# 1         ASSAULT/TRAUMA  39.781627 -86.120826 2006-12-28 04:48:53
# 2                SEIZURE  39.756840 -85.998714 2006-12-28 04:48:53
# 3       UNCONSCIOUS PERS  39.782064 -86.044592 2006-12-28 04:48:53
# 4         *MEDICAL ALARM  39.742415 -86.111559 2006-12-28 04:48:53
# 5         CHEST PAIN/HRT  39.807587 -86.188334 2006-12-28 04:48:53
# 6       UNCONSCIOUS PERS  39.714985 -86.139617 2006-12-28 04:48:53
# 7                SEIZURE  39.640828 -86.052848 2006-12-28 04:48:53
# 8        ABDOMIN/BACK PN  39.746238 -86.126386 2006-12-28 04:48:53
# 9            SICK PERSON  39.806765 -86.178582 2006-12-28 04:48:53
# 10        INJURED PERSON  39.834456 -86.270721 2006-12-28 04:48:53
# 11        CHEST PAIN/HRT  39.753104 -86.045766 2006-12-28 04:48:53
# 12        CHEST PAIN/HRT  39.836041 -86.131476 2006-12-28 04:48:53
# 13               SEIZURE  39.841717 -86.118273 2006-12-28 04:48:53
# 14               SEIZURE  39.749918 -86.148133 2006-12-28 04:48:53
# 15       ABDOMIN/BACK PN  39.893446 -86.043420 2006-12-28 04:48:53
# 16           SICK PERSON  39.814950 -85.968482 2006-12-28 04:48:53
# 17           SICK PERSON  39.746151 -86.027539 2006-12-28 04:48:53
# 18        INJURED PERSON  39.910727 -86.053506 2006-12-28 04:48:53
# 19        DIFF BREATHING  39.716029 -86.156358 2006-12-28 04:48:53
# 20        DIFF BREATHING  39.741917 -86.086566 2006-12-28 04:48:53
# 21        DIFF BREATHING  39.764482 -86.011080 2006-12-28 04:48:53
# 22      UNCONSCIOUS PERS  39.888591 -86.030486 2006-12-28 04:48:53
# 23        CARDIAC ARREST  39.847994 -86.143879 2006-12-28 04:48:53
# 24              DIABETIC  39.764649 -86.086006 2006-12-28 04:48:53
# 25        NONEMER TRANSF  39.912387 -86.196132 2006-12-28 04:48:53
# 26        DIFF BREATHING  39.787920 -86.118243 2006-12-28 04:48:53
# 27           SICK PERSON  39.807636 -86.140814 2006-12-28 04:48:53
# 28            STROKE/CVA  39.814466 -86.087785 2006-12-28 04:48:53
# 29        CHEST PAIN/HRT  39.755125 -86.139951 2006-12-28 04:48:53
# ...                  ...        ...        ...                 ...
# 922509    CHEST PAIN/HRT  39.846429 -86.268734 2006-12-28 04:48:53
# 922510    PERSON CHOKING  39.822807 -86.104453 2006-12-28 04:48:53
# 922511    INJURED PERSON  39.912354 -86.198532 2006-12-28 04:48:53
# 922512   VEHICL/ACCIDENT  39.808649 -86.156837 2006-12-28 04:48:53
# 922513  MENT/ILL/UNSECUR  39.661732 -86.088499 2006-12-28 04:48:53
# 922514    DIFF BREATHING  39.829736 -86.280122 2006-12-28 04:48:53
# 922515  UNCONSCIOUS PERS  39.747821 -86.153181 2006-12-28 04:48:53
# 922516       SICK PERSON  39.778359 -86.094716 2006-12-28 04:48:53
# 922517          OVERDOSE  39.796512 -86.089246 2006-12-28 04:48:53
# 922518  UNCONSCIOUS PERS  39.733401 -86.135652 2006-12-28 04:48:53
# 922519   ABDOMIN/BACK PN  39.772336 -86.103686 2006-12-28 04:48:53
# 922520         APARTMENT  39.789167 -86.155051 2006-12-28 04:48:53
# 922521  ASLT/TRM/UNSECUR  39.794261 -86.116740 2006-12-28 04:48:53
# 922522    INJURED PERSON  39.750790 -86.191017 2006-12-28 04:48:53
# 922523    CHEST PAIN/HRT  39.693630 -86.146656 2006-12-28 04:48:53
# 922524   ABDOMIN/BACK PN  39.772984 -86.113242 2006-12-28 04:48:53
# 922525  BLEEDING/NONTRAU  39.782275 -86.144869 2006-12-28 04:48:53
# 922526    DIFF BREATHING  39.826682 -86.265397 2006-12-28 04:48:53
# 922527  UNCONSCIOUS PERS  39.759639 -86.116519 2006-12-28 04:48:53
# 922528    CARDIAC ARREST  39.771244 -86.067438 2006-12-28 04:48:53
# 922529       SICK PERSON  39.791229 -86.093546 2006-12-28 04:48:53
# 922530  MENTAL ILLNESS-C  39.801780 -86.132286 2006-12-28 04:48:53
# 922531          DIABETIC  39.823714 -86.115232 2006-12-28 04:48:53
# 922532  CARD/ARREST/WRKG  39.848182 -86.137461 2006-12-28 04:48:53
# 922533           SEIZURE  39.850913 -86.145966 2006-12-28 04:48:53
# 922534  UNCONSCIOUS PERS  39.711164 -86.120664 2006-12-28 04:48:53
# 922535       SICK PERSON  39.810525 -86.102691 2006-12-28 04:48:53
# 922536          OVERDOSE  39.903536 -86.044623 2006-12-28 04:48:53
# 922537    DIFF BREATHING  39.808338 -86.105886 2006-12-28 04:48:53
# 922538  BLEEDING/NONTRAU  39.809739 -86.108618 2006-12-28 04:48:53
#
#                 Date_Time
# 0      2006-12-28 04:45:48
# 1      2006-12-28 04:48:53
# 2      2006-12-28 04:52:19
# 3      2006-12-28 05:10:57
# 4      2006-12-28 05:17:56
# 5      2006-12-28 05:19:06
# 6      2006-12-28 05:33:02
# 7      2006-12-28 05:39:16
# 8      2006-12-28 05:49:24
# 9      2006-12-28 06:00:30
# 10     2006-12-28 06:15:15
# 11     2006-12-28 06:09:49
# 12     2006-12-28 06:19:21
# 13     2006-12-28 06:19:46
# 14     2006-12-28 06:25:03
# 15     2006-12-28 06:29:50
# 16     2006-12-28 06:56:45
# 17     2006-12-28 07:09:45
# 18     2006-12-28 07:15:29
# 19     2006-12-28 07:23:00
# 20     2006-12-28 07:28:19
# 21     2006-12-28 07:56:11
# 22     2006-12-28 08:03:39
# 23     2006-12-28 08:00:00
# 24     2006-12-28 08:00:51
# 25     2006-12-28 08:01:17
# 26     2006-12-28 08:10:44
# 27     2006-12-28 08:11:11
# 28     2006-12-28 08:21:39
# 29     2006-12-28 08:26:59
# ...                    ...
# 922509 2016-10-31 21:57:41
# 922510 2016-10-31 22:03:58
# 922511 2016-10-31 22:07:45
# 922512 2016-10-31 22:10:49
# 922513 2016-10-31 22:16:23
# 922514 2016-10-31 22:19:34
# 922515 2016-10-31 22:23:42
# 922516 2016-10-31 22:32:17
# 922517 2016-10-31 22:35:36
# 922518 2016-10-31 22:35:42
# 922519 2016-10-31 22:43:02
# 922520 2016-10-31 22:48:33
# 922521 2016-10-31 22:55:22
# 922522 2016-10-31 22:55:31
# 922523 2016-10-31 22:58:35
# 922524 2016-10-31 23:03:41
# 922525 2016-10-31 23:08:22
# 922526 2016-10-31 23:15:03
# 922527 2016-10-31 23:18:03
# 922528 2016-10-31 23:21:20
# 922529 2016-10-31 23:29:13
# 922530 2016-10-31 23:30:41
# 922531 2016-10-31 23:33:08
# 922532 2016-10-31 23:35:01
# 922533 2016-10-31 23:36:42
# 922534 2016-10-31 23:41:01
# 922535 2016-10-31 23:46:36
# 922536 2016-10-31 23:51:56
# 922537 2016-10-31 23:55:25
# 922538 2016-10-31 23:58:03
#
# [922539 rows x 9 columns]
